# %% [markdown]
# # Planner Example
#
# This is a notebook to test the Plan class (and by extension, all other classes involved in this project).
#
# The expected result here is that you see an "animation" of the paths being generated by the agents on the map, where the paths pop up as they come and are adjusted as needed (in real time).
#
# Visualization is still a very hard thing to do in notebooks, this is WIP.

# %%
from solutions.plan import Plan, sol_individual, sol_coop_individual
from solutions.agent import Agent
from utils.environment import Environment

# %%
env = Environment("../utils/simple.yaml")

# %% [markdown]
# The following example shows 3 agents with different start and goal poses planning on the simple map.

# %%
agents = [Agent("normal", [0, 0], [10, 6], env, 0.75, 200),
          Agent("normal", [0, 5], [4, 6], env, 0.75, 200),
          Agent("normal", [4, -2], [-1.7, 0], env, 0.75, 200)]

plan = Plan(agents, env, sol_individual, sol_coop_individual, 100, viz_trees=False, headless=False)
plan.spin(75)
# Out:
# Runtime completed. Time:  26

# %% [markdown]
# The following example shows one agent planning a path that is difficult for our RRT planner atm. RRT tree is visualized in this scenario for your benefit.

# %%
agents = [Agent("normal", [4, -2], [-1.7, 0], env, 0.3, 200)]

plan = Plan(agents, env, sol_individual, sol_coop_individual, 100, viz_trees=True, headless=False)
plan.spin(50)
# plan.visualizer.spin_once(plan.agents, True)  # If running headless, uncomment to visualize at end.
# Out:
# Runtime completed. Time:  51
