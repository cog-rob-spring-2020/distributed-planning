# %% [markdown]
# # Example of RRT*
#
# This example shows how to use Environment to run RRT*
# Based heavily on the `rrt_examples.ipynb` notebook.

# %%
from shapely.geometry import Point, Polygon

from utils.environment import Environment, plot_environment, plot_poly
from rrtstar import RRTstar

# %%
env = Environment("utils/simple.yaml")

# %%
start = [0, 0]
goal = [10, 6]
goal_sample_rate = 0.8
goal_dist = 0.2
resolution = 0.01

rrt = RRTstar(start, goal, env, goal_dist, goal_sample_rate=goal_sample_rate, path_resolution=resolution, max_iter=2000)

rrt.spin()
rrt.plot_tree()
# Out:
# RRTstar >> starting spin...
# RRTstar >> found a path!
# (6.448728400066124, 5.5)
# RRTstar >> found a path!
